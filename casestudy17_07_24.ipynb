# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/House_Pricing.csv")
data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
data.shape
# Out:
# (21613, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
data.isnull().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
data.ID.unique()
# Out:
# array([7129300520, 6414100192, 5631500400, ..., 1523300141,  291310100,
#        1523300157])

# %%
data['Sale Price'].unique()
# Out:
# array([221900., 538000., 180000., ..., 541800., 610685., 402101.])

# %%
data['Waterfront View'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
data['Date House was Sold'].unique()
# Out:
# array(['14 October 2017', '14 December 2017', '15 February 2016',
#        '14 May 2017', '14 June 2017', '15 January 2016', '15 April 2016',
#        '15 March 2016', '14 July 2017', '14 August 2017',
#        '14 November 2017', '14 September 2017', '15 May 2016'],
#       dtype=object)

# %%
data['No of Times Visited'].unique()
# Out:
# array([nan, 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
data['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
data['Lot Area (in Sqft)'].unique()
# Out:
# array([ 5650.,  7242., 10000., ...,  5813.,  2388.,  1076.])

# %%
data['Flat Area (in Sqft)'].unique()
# Out:
# array([1180., 2570.,  770., ..., 3087., 3118., 1425.])

# %%
data['No of Bathrooms'].mode()
# Out:
# 0    2.5
# Name: No of Bathrooms, dtype: float64

# %%
data['Zipcode'].mode()
# Out:
# 0    98103.0
# Name: Zipcode, dtype: float64

# %%
data['Longitude'].mode()
# Out:
# 0   -122.29
# Name: Longitude, dtype: float64

# %%
if 'No of Times Visited' in data.columns:
    data.drop(columns=['No of Times Visited'], inplace=True)
else:
    print("Column 'No of Times Visited' not found in DataFrame.")

data.isnull().sum()
# Out:
# Column 'No of Times Visited' not found in DataFrame.
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
data.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0               1180.0              5650.0           1.0
# 1               2570.0              7242.0           2.0
# 2                770.0             10000.0           1.0
# 3               1960.0              5000.0           1.0
# 4               1680.0              8080.0           1.0
#
#   Condition of the House  Overall Grade  \
# 0                   Fair              7
# 1                   Fair              7
# 2                   Fair              6
# 3              Excellent              7
# 4                   Fair              8
#
# ...

# %%
sns.histplot(data['Sale Price'],kde=True)
# Out:
# <Axes: xlabel='Sale Price', ylabel='Count'>

# %%
sns.histplot(data['No of Bathrooms'],kde=True)
# Out:
# <Axes: xlabel='No of Bathrooms', ylabel='Count'>

# %%
sns.histplot(data['Flat Area (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Flat Area (in Sqft)', ylabel='Count'>

# %%
sns.histplot(data['Lot Area (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Lot Area (in Sqft)', ylabel='Count'>

# %%
sns.histplot(data['Area of the House from Basement (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Area of the House from Basement (in Sqft)', ylabel='Count'>

# %%
sns.histplot(data['Zipcode'],kde=True)
# Out:
# <Axes: xlabel='Zipcode', ylabel='Count'>

# %%
sns.histplot(data['Living Area after Renovation (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Living Area after Renovation (in Sqft)', ylabel='Count'>

# %%
data['Sale Price'].fillna(data['Sale Price'].median(),inplace=True)
data['No of Bathrooms'].fillna(data['No of Bathrooms'].median(),inplace=True)
data['Flat Area (in Sqft)'].fillna(data['Flat Area (in Sqft)'].median(),inplace=True)
data['Lot Area (in Sqft)'].fillna(data['Lot Area (in Sqft)'].median(),inplace=True)
data['Area of the House from Basement (in Sqft)'].fillna(data['Area of the House from Basement (in Sqft)'].median(),inplace=True)
data['Zipcode'].fillna(data['Zipcode'].median(),inplace=True)
data['Latitude'].fillna(data['Latitude'].median(),inplace=True)
data['Longitude'].fillna(data['Longitude'].median(),inplace=True)
data['Living Area after Renovation (in Sqft)'].fillna(data['Living Area after Renovation (in Sqft)'].median(),inplace=True)
data.isnull().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Sale Price                                 21613 non-null  float64
#  2   No of Bedrooms                             21613 non-null  int64
#  3   No of Bathrooms                            21613 non-null  float64
#  4   Flat Area (in Sqft)                        21613 non-null  float64
#  5   Lot Area (in Sqft)                         21613 non-null  float64
#  6   No of Floors                               21613 non-null  float64
#  7   Condition of the House                     21613 non-null  object
#  8   Overall Grade                              21613 non-null  int64
#  9   Area of the House from Basement (in Sqft)  21613 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt
outliers_columns=['Sale Price','No of Bathrooms','Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Zipcode','Latitude','Longitude','Living Area after Renovation (in Sqft)']
for i in outliers_columns:
  plt.boxplot(data[i])
  plt.title(i)
  plt.show()

# %%
q1=data['Sale Price'].quantile(0.25)
q2=data['Sale Price'].quantile(0.50)
q3=data['Sale Price'].quantile(0.75)
print(q1,q2,q3)
# Out:
# 322000.0 450000.0 645000.0

# %%
IQR=q3-q1
IQR
# Out:
# 323000.0

# %%
min=q1-1.5*IQR
max=q3+1.5*IQR
print(min,max)
# Out:
# -162500.0 1129500.0

# %%
outliers=[]
for i in data['Sale Price']:
  if i<min or i>max:
    outliers.append(i)
print(outliers)
# Out:
# [1230000.0, 2000000.0, 1350000.0, 1330000.0, 1450000.0, 2250000.0, 1510000.0, 2400000.0, 2900000.0, 1370000.0, 2050000.0, 3080000.0, 2380000.0, 1380000.0, 1400000.0, 1350000.0, 1550000.0, 1300000.0, 1450000.0, 1200000.0, 1150000.0, 1390000.0, 1280000.0, 1200000.0, 1490000.0, 2250000.0, 1600000.0, 2130000.0, 1450000.0, 1950000.0, 1220000.0, 3070000.0, 1250000.0, 1150000.0, 1480000.0, 1580000.0, 1300000.0, 1310000.0, 2250000.0, 1360000.0, 1220000.0, 2400000.0, 1270000.0, 1200000.0, 1320000.0, 2450000.0, 1240000.0, 1570000.0, 1130000.0, 1200000.0, 1280000.0, 1960000.0, 1750000.0, 5110000.0, 1150000.0, 1880000.0, 1230000.0, 2300000.0, 2260000.0, 5300000.0, 1200000.0, 2200000.0, 1130000.0, 1180000.0, 1700000.0, 1400000.0, 2540000.0, 1360000.0, 1230000.0, 5350000.0, 1330000.0, 1220000.0, 1250000.0, 1300000.0, 1180000.0, 1380000.0, 1150000.0, 1200000.0, 2250000.0, 1230000.0, 1270000.0, 1680000.0, 1930000.0, 1180000.0, 2350000.0, 1140000.0, 1320000.0, 1430000.0, 1530000.0, 1570000.0, 1130000
# ...

# %%
data['Sale Price']=data['Sale Price'].clip(min,max)

# %%
q1=data['No of Bathrooms'].quantile(0.25)
q2=data['No of Bathrooms'].quantile(0.50)
q3=data['No of Bathrooms'].quantile(0.75)
print(q1,q2,q3)
# Out:
# 1.75 2.25 2.5

# %%
IQR=q3-q1
IQR
# Out:
# 0.75

# %%
min=q1-1.5*IQR
max=q3+1.5*IQR
print(min,max)
# Out:
# 0.625 3.625

# %%
outliers=[]
for i in data['No of Bathrooms']:
  if i<min or i>max:
    outliers.append(i)
print(outliers)
# Out:
# [4.5, 4.0, 4.0, 4.75, 5.0, 4.25, 4.5, 4.25, 3.75, 5.0, 4.0, 4.0, 4.25, 4.25, 0.0, 4.25, 4.5, 4.5, 3.75, 4.5, 4.0, 0.0, 4.5, 5.25, 4.0, 3.75, 4.5, 4.5, 4.25, 6.0, 3.75, 4.25, 4.0, 3.75, 3.75, 4.75, 5.0, 3.75, 3.75, 3.75, 5.0, 4.25, 3.75, 4.0, 4.25, 4.5, 3.75, 4.0, 3.75, 5.0, 3.75, 4.0, 3.75, 3.75, 4.25, 4.0, 4.25, 4.25, 4.5, 3.75, 4.0, 3.75, 5.0, 3.75, 0.5, 4.0, 5.0, 5.0, 4.5, 5.5, 4.25, 4.0, 4.5, 3.75, 3.75, 4.5, 3.75, 5.5, 4.25, 5.5, 0.0, 5.25, 4.25, 4.0, 4.5, 3.75, 3.75, 3.75, 3.75, 4.25, 4.5, 4.75, 3.75, 3.75, 3.75, 3.75, 3.75, 4.5, 4.25, 4.0, 4.75, 4.75, 3.75, 4.5, 4.0, 3.75, 3.75, 4.0, 4.0, 3.75, 4.75, 4.5, 3.75, 6.75, 6.0, 4.5, 5.5, 4.5, 3.75, 4.0, 4.25, 3.75, 5.75, 3.75, 4.0, 4.0, 4.0, 5.25, 4.75, 4.0, 4.25, 3.75, 4.0, 4.0, 5.25, 3.75, 3.75, 3.75, 4.5, 5.0, 3.75, 3.75, 4.5, 4.0, 3.75, 3.75, 4.0, 4.75, 3.75, 0.0, 4.25, 5.0, 3.75, 4.0, 4.25, 4.0, 4.0, 4.5, 4.75, 4.0, 4.0, 4.0, 4.5, 3.75, 3.75, 4.5, 5.75, 4.75, 3.75, 4.0, 4.0, 3.75, 4.25, 4.25, 3.75, 0.0, 4.5, 5.5, 4.0, 4.5, 4.5,
# ...

# %%
data['No of Bathrooms']=data['No of Bathrooms'].clip(min,max)

# %%
q1=data['Flat Area (in Sqft)'].quantile(0.25)
q2=data['Flat Area (in Sqft)'].quantile(0.50)
q3=data['Flat Area (in Sqft)'].quantile(0.75)
print(q1,q2,q3)
# Out:
# 1430.0 1910.0 2550.0

# %%
IQR=q3-q1
IQR
# Out:
# 1120.0

# %%
min=q1-1.5*IQR
max=q3+1.5*IQR
print(min,max)
# Out:
# -250.0 4230.0

# %%
outliers=[]
for i in data['Flat Area (in Sqft)']:
  if i<min or i>max:
    outliers.append(i)
print(outliers)
# Out:
# [5420.0, 4770.0, 4380.0, 5180.0, 4410.0, 5050.0, 5310.0, 4550.0, 4290.0, 4290.0, 4800.0, 6070.0, 4870.0, 4860.0, 4860.0, 4410.0, 4760.0, 6050.0, 4740.0, 5403.0, 4380.0, 4640.0, 6050.0, 4370.0, 4570.0, 4670.0, 4860.0, 4270.0, 4890.0, 4390.0, 4250.0, 5670.0, 4475.0, 6070.0, 4300.0, 4390.0, 8010.0, 4460.0, 4610.0, 4380.0, 4250.0, 4930.0, 7390.0, 4640.0, 5320.0, 8000.0, 6563.0, 4740.0, 5450.0, 4440.0, 4830.0, 4280.0, 4570.0, 4370.0, 5710.0, 5620.0, 5774.0, 4470.0, 4490.0, 5040.0, 5770.0, 5180.0, 6400.0, 4490.0, 6055.0, 4250.0, 6300.0, 4350.0, 4460.0, 4340.0, 4250.0, 5110.0, 4700.0, 4910.0, 4750.0, 6840.0, 4930.0, 5180.0, 5130.0, 6640.0, 5740.0, 7350.0, 4510.0, 4300.0, 4870.0, 5020.0, 4740.0, 5370.0, 4860.0, 6930.0, 6550.0, 6110.0, 4883.0, 5010.0, 4660.0, 4600.0, 4910.0, 5410.0, 4270.0, 4520.0, 5340.0, 5230.0, 5370.0, 4730.0, 4430.0, 5780.0, 6240.0, 10040.0, 4250.0, 5360.0, 4610.0, 7480.0, 5620.0, 4340.0, 7080.0, 5760.0, 4400.0, 4280.0, 9200.0, 4320.0, 4420.0, 4380.0, 4580.0, 5310.0, 4660
# ...

# %%
data['Flat Area (in Sqft)']=data['Flat Area (in Sqft)'].clip(min,max)

# %%
q1=data['Lot Area (in Sqft)'].quantile(0.25)
q2=data['Lot Area (in Sqft)'].quantile(0.50)
q3=data['Lot Area (in Sqft)'].quantile(0.75)
print(q1,q2,q3)
# Out:
# 5040.0 7617.5 10685.0

# %%
IQR=q3-q1
IQR
# Out:
# 5645.0

# %%
min=q1-1.5*IQR
max=q3+1.5*IQR
print(min,max)
# Out:
# -3427.5 19152.5

# %%
outliers=[]
for i in data['Lot Area (in Sqft)']:
  if i<min or i>max:
    outliers.append(i)
print(outliers)
# Out:
# [101930.0, 19901.0, 44867.0, 34848.0, 24186.0, 65005.0, 21235.0, 20158.0, 50094.0, 50529.0, 35102.0, 39683.0, 41800.0, 36847.0, 107593.0, 33919.0, 28037.0, 111078.0, 315374.0, 60984.0, 19850.0, 25245.0, 38332.0, 21000.0, 35003.0, 66211.0, 155073.0, 33474.0, 19436.0, 28040.0, 94300.0, 221284.0, 36224.0, 40510.0, 20100.0, 57346.0, 26300.0, 49375.0, 22111.0, 78408.0, 64904.0, 45004.0, 43995.0, 20000.0, 32633.0, 19800.0, 77972.0, 29970.0, 40438.0, 69415.0, 209959.0, 26977.0, 25600.0, 22357.0, 40139.0, 143947.0, 32239.0, 37461.0, 174240.0, 171626.0, 27260.0, 19700.0, 219978.0, 24920.0, 20978.0, 28025.0, 181319.0, 19635.0, 57063.0, 39150.0, 194278.0, 230652.0, 36947.0, 76230.0, 24069.0, 40518.0, 29242.0, 29170.0, 108900.0, 217014.0, 22370.0, 75794.0, 84942.0, 217800.0, 32666.0, 31465.0, 34293.0, 26326.0, 36400.0, 55867.0, 22267.0, 209523.0, 19252.0, 23488.0, 25958.0, 26055.0, 39478.0, 51836.0, 37769.0, 72745.0, 22594.0, 218252.0, 31400.0, 23680.0, 40419.0, 34133.0, 36276.0, 40097.0, 36085.
# ...

# %%
data['Lot Area (in Sqft)']=data['Lot Area (in Sqft)'].clip(min,max)

# %%
q1=np.percentile(data['Area of the House from Basement (in Sqft)'],25)
q2=np.percentile(data['Area of the House from Basement (in Sqft)'],50)
q3=np.percentile(data['Area of the House from Basement (in Sqft)'],75)
print(q1,q2,q3)
# Out:
# 1190.0 1560.0 2210.0

# %%
IQR=q3-q1
IQR
# Out:
# 1020.0

# %%
min=q1-1.5*IQR
max=q3+1.5*IQR
print(min,max)
# Out:
# -340.0 3740.0

# %%
outliers=[]
for i in data['Area of the House from Basement (in Sqft)']:
  if i<min or i>max:
    outliers.append(i)
print(outliers)
# Out:
# [3890.0, 3760.0, 4750.0, 5310.0, 3840.0, 6070.0, 4040.0, 3840.0, 4860.0, 3860.0, 4410.0, 6050.0, 4740.0, 5403.0, 4120.0, 4150.0, 4370.0, 4570.0, 4670.0, 4230.0, 4270.0, 5670.0, 4475.0, 6070.0, 4300.0, 3990.0, 5990.0, 4460.0, 4190.0, 4250.0, 4930.0, 3840.0, 5000.0, 5320.0, 6720.0, 4210.0, 3890.0, 3830.0, 5153.0, 4210.0, 4740.0, 5450.0, 4280.0, 3880.0, 4570.0, 3750.0, 4130.0, 5710.0, 4700.0, 3810.0, 4490.0, 4150.0, 4070.0, 3840.0, 5770.0, 4030.0, 3810.0, 4490.0, 3840.0, 4360.0, 3960.0, 4460.0, 4340.0, 3850.0, 4750.0, 4350.0, 4160.0, 5180.0, 4070.0, 5130.0, 6350.0, 3770.0, 3780.0, 4750.0, 3950.0, 3915.0, 3880.0, 4870.0, 4030.0, 4740.0, 3850.0, 4860.0, 4310.0, 3930.0, 4070.0, 4080.0, 5400.0, 6110.0, 3859.0, 4600.0, 3940.0, 3800.0, 4230.0, 4070.0, 5050.0, 4000.0, 4220.0, 3860.0, 3890.0, 3890.0, 5230.0, 5370.0, 4140.0, 4270.0, 4430.0, 4210.0, 4130.0, 3780.0, 4610.0, 7680.0, 4250.0, 3820.0, 4120.0, 3770.0, 4610.0, 5080.0, 4140.0, 4340.0, 3770.0, 5760.0, 4390.0, 4000.0, 3810.0, 4400.0, 6200.
# ...

# %%
data['Area of the House from Basement (in Sqft)']=data['Area of the House from Basement (in Sqft)'].clip(min,max)

# %%
q1=data['Zipcode'].quantile(0.25)
q2=data['Zipcode'].quantile(0.50)
q3=data['Zipcode'].quantile(0.75)
print(q1,q2,q3)
# Out:
# 98033.0 98065.0 98118.0

# %%
IQR=q3-q1
IQR
# Out:
# 85.0

# %%
min=q1-1.5*IQR
max=q3+1.5*IQR
print(min,max)
# Out:
# 97905.5 98245.5

# %%
outliers=[]
for i in data['Zipcode']:
  if i<min or i>max:
    outliers.append(i)
print(outliers)
# Out:
# []

# %%
data['Zipcode']=data['Zipcode'].clip(min,max)

# %%
q1=data['Latitude'].quantile(0.25)
q2=data['Latitude'].quantile(0.50)
q3=data['Latitude'].quantile(0.75)
print(q1,q2,q3)
# Out:
# 47.471 47.5718 47.678

# %%
IQR=q3-q1
IQR
# Out:
# 0.20700000000000074

# %%
min=q1-1.5*IQR
max=q3+1.5*IQR
print(min,max)
# Out:
# 47.1605 47.9885

# %%
outliers=[]
for i in data['Latitude']:
  if i<min or i>max:
    outliers.append(i)
print(outliers)
# Out:
# [47.1559, 47.1593]

# %%
data['Latitude']=data['Latitude'].clip(min,max)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Sale Price                                 21613 non-null  float64
#  2   No of Bedrooms                             21613 non-null  int64
#  3   No of Bathrooms                            21613 non-null  float64
#  4   Flat Area (in Sqft)                        21613 non-null  float64
#  5   Lot Area (in Sqft)                         21613 non-null  float64
#  6   No of Floors                               21613 non-null  float64
#  7   Condition of the House                     21613 non-null  object
#  8   Overall Grade                              21613 non-null  int64
#  9   Area of the House from Basement (in Sqft)  21613 non-null  float64
# ...

# %%
categorical_cols=['Condition of the House']
numerical_cols=[' Sale Price','No of Bathrooms','Flat Area (in Sqft)','No of Floors','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Zipcode','Latitude','Longitude','Living Area after Renovation (in Sqft)']

# %%
data_encoded=pd.get_dummies(data,columns=categorical_cols,dtype=int,drop_first=True)
data_encoded.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0               1180.0              5650.0           1.0              7
# 1               2570.0              7242.0           2.0              7
# 2                770.0             10000.0           1.0              6
# 3               1960.0              5000.0           1.0              7
# 4               1680.0              8080.0           1.0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# 0                                     1180.0                        0  ...
# ...

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Sale Price                                 21613 non-null  float64
#  2   No of Bedrooms                             21613 non-null  int64
#  3   No of Bathrooms                            21613 non-null  float64
#  4   Flat Area (in Sqft)                        21613 non-null  float64
#  5   Lot Area (in Sqft)                         21613 non-null  float64
#  6   No of Floors                               21613 non-null  float64
#  7   Overall Grade                              21613 non-null  int64
#  8   Area of the House from Basement (in Sqft)  21613 non-null  float64
#  9   Basement Area (in Sqft)                    21613 non-null  int64
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
numerical_cols = ['Sale Price', 'No of Bathrooms', 'Flat Area (in Sqft)', 'No of Floors',
                 'Lot Area (in Sqft)', 'Area of the House from Basement (in Sqft)',
                 'Zipcode', 'Latitude', 'Longitude', 'Living Area after Renovation (in Sqft)']

data_std_scaled = data_encoded.copy()

std_scaler = StandardScaler()
data_std_scaled[numerical_cols] = std_scaler.fit_transform(data_std_scaled[numerical_cols])

data_std_scaled = pd.DataFrame(data_std_scaled, columns=data_encoded.columns)
data_std_scaled.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520   -0.866430               3        -1.447640
# 1  6414100192   -0.005939               3         0.175628
# 2  5631500400   -0.980490               2        -1.447640
# 3  2487200875    0.173727               4         1.149589
# 4  1954400510   -0.082161               3        -0.149026
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0            -0.979940           -0.228268     -0.915427              7
# 1             0.533757           -0.189832      0.936506              7
# 2            -1.426426           -0.123244     -0.915427              6
# 3            -0.130528           -0.243962     -0.915427              7
# 4            -0.435445           -0.169600     -0.915427              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# 0                                  -0.734756                        0  ...
# ...

# %%
data_std_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Sale Price                                 21613 non-null  float64
#  2   No of Bedrooms                             21613 non-null  int64
#  3   No of Bathrooms                            21613 non-null  float64
#  4   Flat Area (in Sqft)                        21613 non-null  float64
#  5   Lot Area (in Sqft)                         21613 non-null  float64
#  6   No of Floors                               21613 non-null  float64
#  7   Overall Grade                              21613 non-null  int64
#  8   Area of the House from Basement (in Sqft)  21613 non-null  float64
#  9   Basement Area (in Sqft)                    21613 non-null  int64
# ...

# %%
data_std_scaled.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.161300e+04    21613.000000     2.161300e+04
# mean   4.580302e+09  4.471097e-17        3.370842    -1.578034e-16
# std    2.876566e+09  1.000023e+00        0.930062     1.000023e+00
# min    1.000102e+06 -1.266323e+00        0.000000    -2.746255e+00
# 25%    2.123049e+09 -5.939366e-01        3.000000    -4.736791e-01
# 50%    3.904930e+09 -2.454937e-01        3.000000     1.756281e-01
# 75%    7.308900e+09  2.853373e-01        4.000000     5.002817e-01
# max    9.900000e+09  1.949053e+01       33.000000     7.642662e+00
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         2.161300e+04        2.161300e+04  2.161300e+04   21613.000000
# mean          1.683236e-16       -1.052023e-17 -3.156068e-17       7.623467
# std           1.000023e+00        1.000023e+00  1.000023e+00       1.105439
# ...

# %%
data_MinMax_scaled=data_encoded.copy()

MinMax_scaler=StandardScaler()
data_MinMax_scaled[numerical_cols] = std_scaler.fit_transform(data_MinMax_scaled[numerical_cols])

data_MinMax_scaled = pd.DataFrame(data_MinMax_scaled, columns=data_encoded.columns)
data_MinMax_scaled.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520   -0.866430               3        -1.447640
# 1  6414100192   -0.005939               3         0.175628
# 2  5631500400   -0.980490               2        -1.447640
# 3  2487200875    0.173727               4         1.149589
# 4  1954400510   -0.082161               3        -0.149026
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0            -0.979940           -0.228268     -0.915427              7
# 1             0.533757           -0.189832      0.936506              7
# 2            -1.426426           -0.123244     -0.915427              6
# 3            -0.130528           -0.243962     -0.915427              7
# 4            -0.435445           -0.169600     -0.915427              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# 0                                  -0.734756                        0  ...
# ...

# %%
data_MinMax_scaled.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.161300e+04    21613.000000     2.161300e+04
# mean   4.580302e+09  4.471097e-17        3.370842    -1.578034e-16
# std    2.876566e+09  1.000023e+00        0.930062     1.000023e+00
# min    1.000102e+06 -1.266323e+00        0.000000    -2.746255e+00
# 25%    2.123049e+09 -5.939366e-01        3.000000    -4.736791e-01
# 50%    3.904930e+09 -2.454937e-01        3.000000     1.756281e-01
# 75%    7.308900e+09  2.853373e-01        4.000000     5.002817e-01
# max    9.900000e+09  1.949053e+01       33.000000     7.642662e+00
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         2.161300e+04        2.161300e+04  2.161300e+04   21613.000000
# mean          1.683236e-16       -1.052023e-17 -3.156068e-17       7.623467
# std           1.000023e+00        1.000023e+00  1.000023e+00       1.105439
# ...

# %%
corr_columns=['Sale Price','No of Bedrooms','No of Bathrooms','Flat Area (in Sqft)','Lot Area (in Sqft)','No of Floors']
original_data_corr=data_encoded[corr_columns].corr()
original_data_corr.head()
# Out:
#                      Sale Price  No of Bedrooms  No of Bathrooms  \
# Sale Price             1.000000        0.308366         0.525041
# No of Bedrooms         0.308366        1.000000         0.515866
# No of Bathrooms        0.525041        0.515866         1.000000
# Flat Area (in Sqft)    0.702024        0.576566         0.754565
# Lot Area (in Sqft)     0.089568        0.031668         0.087717
#
#                      Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors
# Sale Price                      0.702024            0.089568      0.256836
# No of Bedrooms                  0.576566            0.031668      0.175429
# No of Bathrooms                 0.754565            0.087717      0.500575
# Flat Area (in Sqft)             1.000000            0.172723      0.353875
# Lot Area (in Sqft)              0.172723            1.000000     -0.005218

# %%
scaled_data_corr=data_std_scaled[corr_columns].corr()
scaled_data_corr.head()
# Out:
#                      Sale Price  No of Bedrooms  No of Bathrooms  \
# Sale Price             1.000000        0.308366         0.525041
# No of Bedrooms         0.308366        1.000000         0.515866
# No of Bathrooms        0.525041        0.515866         1.000000
# Flat Area (in Sqft)    0.702024        0.576566         0.754565
# Lot Area (in Sqft)     0.089568        0.031668         0.087717
#
#                      Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors
# Sale Price                      0.702024            0.089568      0.256836
# No of Bedrooms                  0.576566            0.031668      0.175429
# No of Bathrooms                 0.754565            0.087717      0.500575
# Flat Area (in Sqft)             1.000000            0.172723      0.353875
# Lot Area (in Sqft)              0.172723            1.000000     -0.005218

# %%
minmax_data_corr=data_MinMax_scaled[corr_columns].corr()
minmax_data_corr.head()
# Out:
#                      Sale Price  No of Bedrooms  No of Bathrooms  \
# Sale Price             1.000000        0.308366         0.525041
# No of Bedrooms         0.308366        1.000000         0.515866
# No of Bathrooms        0.525041        0.515866         1.000000
# Flat Area (in Sqft)    0.702024        0.576566         0.754565
# Lot Area (in Sqft)     0.089568        0.031668         0.087717
#
#                      Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors
# Sale Price                      0.702024            0.089568      0.256836
# No of Bedrooms                  0.576566            0.031668      0.175429
# No of Bathrooms                 0.754565            0.087717      0.500575
# Flat Area (in Sqft)             1.000000            0.172723      0.353875
# Lot Area (in Sqft)              0.172723            1.000000     -0.005218

# %%
sns.heatmap(original_data_corr,annot=True)
# Out:
# <Axes: >
